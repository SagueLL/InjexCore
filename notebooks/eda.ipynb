# %%
import pandas as pd

df = pd.read_csv("../data/raw/dataset_pro.csv")

df.head()
# Out:
#                        tiempo  ciclo_id  temperatura_material  \
# 0  2026-05-05 16:35:22.180917         0            221.490142
# 1  2026-05-05 16:36:02.180917         1            212.164353
# 2  2026-05-05 16:36:42.180917         2            216.551019
# 3  2026-05-05 16:37:22.180917         3            220.661915
# 4  2026-05-05 16:38:02.180917         4            217.490347
#
#    temperatura_molde  presion_inyeccion  presion_mantenimiento  \
# 0          49.585207         307.250014             198.731027
# 1          52.851109         295.432534             189.622828
# 2          51.127094         298.981024             240.760422
# 3          52.645283         277.843228             189.323684
# 4          49.072363         309.774756             216.616010
#
#    presion_cavidad  velocidad_inyeccion  posicion_tornillo  tiempo_inyeccion  \
# 0       224.660873            86.476885         102.712800          3.473764
# ...

# %%
df.info()
df.describe()
df["estado"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tiempo                 2000 non-null   str
#  1   ciclo_id               2000 non-null   int64
#  2   temperatura_material   2000 non-null   float64
#  3   temperatura_molde      2000 non-null   float64
#  4   presion_inyeccion      2000 non-null   float64
#  5   presion_mantenimiento  2000 non-null   float64
#  6   presion_cavidad        2000 non-null   float64
#  7   velocidad_inyeccion    2000 non-null   float64
#  8   posicion_tornillo      2000 non-null   float64
#  9   tiempo_inyeccion       2000 non-null   float64
#  10  tiempo_enfriamiento    2000 non-null   float64
#  11  tiempo_ciclo           2000 non-null   float64
#  12  volumen_especifico     2000 non-null   float64
#  13  energia_consumida      2000 non-null   float64
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(df["temperatura_material"])
plt.title("Temperatura del material (con drift)")
plt.xlabel("Ciclo")
plt.ylabel("Temperatura")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(df["presion_inyeccion"])
plt.title("Presión de la inyección (con drift)")
plt.xlabel("Ciclo")
plt.ylabel("Presión")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(df["tiempo_ciclo"])
plt.title("Tiempo de un Ciclo (con drift)")
plt.xlabel("Ciclo")
plt.ylabel("Tiempo")
plt.show()
